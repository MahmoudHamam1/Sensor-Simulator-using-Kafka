# %%
from time import sleep
from json import dumps
from kafka import KafkaProducer
import time
import random
import json

# %%
producer = KafkaProducer(bootstrap_servers=['localhost:9093'],
                         value_serializer=lambda x: 
                         dumps(x).encode('utf-8'))

# %%
reg=['Central','Eastern']
level=['1','2','3','4']
maxelec=1000000000
minelec=100000000
maxtemp=90
mintemp=40
minmotion=0
maxmotion=100
maxhue=100
minhue=20
hometype=['flat','villa']
comm=['yes','no']

# %%
while True:
    mytime=str(time.gmtime()[0])+ '/' + str(time.gmtime()[1]) + '/' + str(time.gmtime()[2])+','+str(time.gmtime()[3])+ ':' + str(time.gmtime()[4]) + ':' + str(time.gmtime()[5])
    temp= int(random.uniform(maxtemp,mintemp))
    motion= int(random.uniform(maxmotion,minmotion))
    hue= int(random.uniform(maxhue,minhue))
    lvl= int(random.uniform(0,len(level)))
    home= int(random.uniform(0,len(hometype)))
    commercial= int(random.uniform(0,len(comm)))
    power= round(random.uniform(maxelec,minelec),3)
    dat= "" +str(temp)+ ";" +str(hue)+';'+str(motion)+';'+hometype[home]+';'+comm[commercial]+';'+ str(level[lvl]) +";"+mytime+';'+ str(power)
    producer.send('numtest', value=dat)
    print(dat)
    sleep(5)
# Out:
# 87;22;58;villa;yes;4;2019/3/20,13:33:26;925896392.354
# 52;74;38;flat;yes;4;2019/3/20,13:33:31;633517486.378
# 65;78;89;flat;no;2;2019/3/20,13:33:36;386650114.341
# 86;26;28;flat;no;3;2019/3/20,13:33:41;572798289.258
# 66;81;40;flat;no;4;2019/3/20,13:33:46;693633707.167
# 50;46;62;flat;no;3;2019/3/20,13:33:51;956512642.431
# 63;21;10;flat;yes;4;2019/3/20,13:33:56;652664969.062
# 54;64;56;villa;yes;3;2019/3/20,13:34:1;590141397.484
# 64;27;6;flat;no;1;2019/3/20,13:34:6;271460983.915
# 53;30;27;villa;no;1;2019/3/20,13:34:11;617878523.708
# 43;91;19;flat;no;1;2019/3/20,13:34:16;128576236.007
# 85;77;15;villa;no;1;2019/3/20,13:34:21;414994974.401
# 44;86;76;flat;no;4;2019/3/20,13:34:26;913578817.94
# 59;91;49;flat;yes;4;2019/3/20,13:34:31;233640968.953
# 69;61;66;villa;yes;2;2019/3/20,13:34:36;668990640.845
# 53;80;55;flat;yes;3;2019/3/20,13:34:41;387086957.629
# 87;79;38;flat;no;1;2019/3/20,13:34:46;553550842.293
# 72;99;0;villa;yes;4;2019/3/20,13:34:51;610299985.045
# ...
